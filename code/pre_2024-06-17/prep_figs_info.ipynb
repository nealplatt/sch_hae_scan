# %%
import pandas as pd
from pathlib import Path
import os

# %%
proj_dir="/master/nplatt/sch_hae_scan"
results_dir=f"{proj_dir}/results"
os.chdir(results_dir)

# %%
Path(f"{results_dir}/fig_plotting_info").mkdir(parents=True, exist_ok=True)
os.chdir(f"{results_dir}/fig_plotting_info")

# %%
spacer_size=2_500_000

# %%
len_df = pd.read_csv(f"{proj_dir}/data/GCF_000699445.3_UoM_Shae.V3_genomic.fna.fai", sep="\t")
len_df.columns=["contig", "length", "offset", "linebases", "linewidth"]

len_df['cumsum'] = len_df['length'].shift().cumsum().fillna(0)

contig_offset = len_df.set_index('contig')['cumsum'].to_dict()
spacers = {contig: i * spacer_size for i, contig in enumerate(contig_offset.keys())}

len_df[["x_offset", "x_start", "x_end", "mid_tick", "color"]]="na"

for contig in contig_offset.keys():
    contig_offset[contig] += spacers[contig]

for index, row in len_df.iterrows():
    contig = row["contig"]
    length = row["length"]
    
    offset = contig_offset[contig]
    start  = offset
    end    = start + length
    tick   = (start + length)/2
    
    len_df.loc[len_df["contig"]==contig, "x_offset"] = offset
    len_df.loc[len_df["contig"]==contig, "x_start"] = start
    len_df.loc[len_df["contig"]==contig, "x_end"] = end
    len_df.loc[len_df["contig"]==contig, "mid_tick"] = tick
    
len_df.drop(["offset", "linebases", "linewidth", "cumsum"], axis=1, inplace=True)

len_df
# Out:
#              contig    length     x_offset      x_start        x_end  \
# 0       NC_067196.1  93306550          0.0          0.0   93306550.0
# 1       NC_067197.1  47367863   95806550.0   95806550.0  143174413.0
# 2       NC_067198.1  48328128  145674413.0  145674413.0  194002541.0
# 3       NC_067199.1  46771736  196502541.0  196502541.0  243274277.0
# 4       NC_067200.1  22148653  245774277.0  245774277.0  267922930.0
# ..              ...       ...          ...          ...          ...
# 157  NW_026137016.1     25648  703244390.0  703244390.0  703270038.0
# 158  NW_026137017.1     52804  705770038.0  705770038.0  705822842.0
# 159  NW_026137018.1     33027  708322842.0  708322842.0  708355869.0
# 160  NW_026137003.1    209180  710855869.0  710855869.0  711065049.0
# 161  NW_026137019.1     38348  713565049.0  713565049.0  713603397.0
#
#         mid_tick color
# 0     46653275.0    na
# 1     71587206.5    na
# 2     97001270.5    na
# 3    121637138.5    na
# 4    133961465.0    na
# ..           ...   ...
# 157  351635019.0    na
# 158  352911421.0    na
# 159  354177934.5    na
# 160  355532524.5    na
# 161  356801698.5    na
#
# [162 rows x 7 columns]

# %%
contigs = len_df['contig']
colors= ["#078d70", "#7bade3", "#3e1a78"]*50000
color_map = dict(zip(contigs, colors))

colors=[]

for index, row in len_df.iterrows():
    colors.append(color_map[row['contig']])
    
len_df["color"] = colors
len_df
# Out:
#              contig    length     x_offset      x_start        x_end  \
# 0       NC_067196.1  93306550          0.0          0.0   93306550.0
# 1       NC_067197.1  47367863   95806550.0   95806550.0  143174413.0
# 2       NC_067198.1  48328128  145674413.0  145674413.0  194002541.0
# 3       NC_067199.1  46771736  196502541.0  196502541.0  243274277.0
# 4       NC_067200.1  22148653  245774277.0  245774277.0  267922930.0
# ..              ...       ...          ...          ...          ...
# 157  NW_026137016.1     25648  703244390.0  703244390.0  703270038.0
# 158  NW_026137017.1     52804  705770038.0  705770038.0  705822842.0
# 159  NW_026137018.1     33027  708322842.0  708322842.0  708355869.0
# 160  NW_026137003.1    209180  710855869.0  710855869.0  711065049.0
# 161  NW_026137019.1     38348  713565049.0  713565049.0  713603397.0
#
#         mid_tick    color
# 0     46653275.0  #078d70
# 1     71587206.5  #7bade3
# 2     97001270.5  #3e1a78
# 3    121637138.5  #078d70
# 4    133961465.0  #7bade3
# ..           ...      ...
# 157  351635019.0  #7bade3
# 158  352911421.0  #3e1a78
# 159  354177934.5  #078d70
# 160  355532524.5  #7bade3
# 161  356801698.5  #3e1a78
#
# [162 rows x 7 columns]

# %%
len_df.to_csv("plotting_info.csv", sep=",", index=False, header=True, na_rep="Na")
