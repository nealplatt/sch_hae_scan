# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import vcf

# %%
proj_dir="/master/nplatt/sch_hae_scan"

# %% [markdown]
# # TWISST: Phylogenetic identification of introgressed genomic regions

# %%
Path("{}/results/twisst/play".format(proj_dir)).mkdir(parents=True, exist_ok=True)
os.chdir("{}/results/twisst/play".format(proj_dir))

# %%
input_vcf_path="twisst.recode.vcf"

# %%
import os
import vcf
import re
from collections import defaultdict
import sys
#from tqdm import tqdm
from pathlib import Path
import glob
import pandas as pd

# %%
# !pwd
# Out:
# /master/nplatt/sch_hae_scan/results/twisst/play

# %%
vcf_file_list=sys.argv[1]
o_cord_file=sys.argv[2]

vcf_file_list="vcf.list"
o_cord_file="coordinates.csv"

# %%
vcf = "test.vcf"

# %%
window_size=100

for i_vcf_file in vcfs:
    #o_phy_file = "{}.phylip".format(i_vcf_file)

    vcf_reader = vcf.Reader(filename=i_vcf_file)
    samples = vcf_reader.samples

    # Defining a dict
    seqs=defaultdict(str)

    chrom="na"
    start=1e12
    stop=-1

    records=[]
    for record in vcf_reader:
        chrom = record.CHROM
        
        if len(records < window_size):
            records.append(record)
            
            
            if records 
        
        
        
        
#         pos=record.POS
#         if record.POS < start:
#             start = record.POS

#         if record.POS > stop:
#             stop = record.POS

#         chrom = record.CHROM

#         for sample in samples:
#             ref_allele=str(record.REF)
#             alt_allele=str(record.ALT[0])

#             h1 = re.split("\\|", record.genotype(sample)['GT'].replace("/", "|"))[0]
#             h2 = re.split("\\|", record.genotype(sample)['GT'].replace("/", "|"))[1]

#             if h1 == "0":
#                 h1=ref_allele
#             if h1 == "1":
#                 h1=alt_allele

#             if h2 == "0":
#                 h2=ref_allele
#             if h2 == "1":
#                 h2=alt_allele

#             if h1 == ".":
#                 h1="?"
#             if h2 == ".":
#                 h2 = "?"

#             seqs["{}_h1".format(sample)]+=h1
#             seqs["{}_h2".format(sample)]+=h2
#             # seqs["{}_h1".format(sample)].append(h1)
#             # seqs["{}_h2".format(sample)].append(h2)

#     num_samples = len(seqs.keys())
#     seq_len = len(seqs["{}_h1".format(samples[0])])


#     num_samples = len(seqs.keys())
#     seq_len = len(seqs["{}_h1".format(samples[0])])


#     with open(o_phy_file, 'w') as outf:
#         outf.write("{} {}\n".format(num_samples, seq_len))
#         for h_id in seqs:
#             seq=seqs[h_id]
#             outf.write("{}\t{}\n".format(h_id, seq))

#     with open(o_cord_file, 'a') as outf:
#         prefix = os.path.basename(i_vcf_file).replace(".vcf", "")
#         outf.write("{},{},{},{}\n".format(prefix, chrom, start, stop))

# %%
# with open('vcf.list', 'r') as file:
#     # Read all lines from the file into a list
#     vcfs = [line.rstrip() for line in file.readlines()]
# vcfs

# %%
for i_vcf_file in tqdm(vcfs):
    o_phy_file = "{}.phylip".format(i_vcf_file)

    vcf_reader = vcf.Reader(filename=i_vcf_file)
    samples = vcf_reader.samples

    # Defining a dict
    seqs=defaultdict(str)

    chrom="na"
    start=1e12
    stop=-1

    for record in vcf_reader:
        pos=record.POS
        if record.POS < start:
            start = record.POS

        if record.POS > stop:
            stop = record.POS

        chrom = record.CHROM

        for sample in samples:
            ref_allele=str(record.REF)
            alt_allele=str(record.ALT[0])

            h1 = re.split("\\|", record.genotype(sample)['GT'].replace("/", "|"))[0]
            h2 = re.split("\\|", record.genotype(sample)['GT'].replace("/", "|"))[1]

            if h1 == "0":
                h1=ref_allele
            if h1 == "1":
                h1=alt_allele

            if h2 == "0":
                h2=ref_allele
            if h2 == "1":
                h2=alt_allele

            if h1 == ".":
                h1="?"
            if h2 == ".":
                h2 = "?"

            seqs["{}_h1".format(sample)]+=h1
            seqs["{}_h2".format(sample)]+=h2
            # seqs["{}_h1".format(sample)].append(h1)
            # seqs["{}_h2".format(sample)].append(h2)

    num_samples = len(seqs.keys())
    seq_len = len(seqs["{}_h1".format(samples[0])])


    num_samples = len(seqs.keys())
    seq_len = len(seqs["{}_h1".format(samples[0])])


    with open(o_phy_file, 'w') as outf:
        outf.write("{} {}\n".format(num_samples, seq_len))
        for h_id in seqs:
            seq=seqs[h_id]
            outf.write("{}\t{}\n".format(h_id, seq))

    with open(o_cord_file, 'a') as outf:
        prefix = os.path.basename(i_vcf_file).replace(".vcf", "")
        outf.write("{},{},{},{}\n".format(prefix, chrom, start, stop))

# %%
haploid_samples
# Out:
# [Call(sample=Sb_NG_au_1.2_0_0, ['0', '0']),
#  Call(sample=Sb_NG_au_1.2_0_1, ['0', '0']),
#  Call(sample=Sb_NG_au_2.10_0_0, ['0', '0']),
#  Call(sample=Sb_NG_au_2.10_0_1, ['0', '0']),
#  Call(sample=Sb_NG_au_2.13_0_0, ['0', '0']),
#  Call(sample=Sb_NG_au_2.13_0_1, ['0', '0']),
#  Call(sample=Sb_NG_au_2.5_0_0, ['0', '0']),
#  Call(sample=Sb_NG_au_2.5_0_1, ['0', '0']),
#  Call(sample=Sb_NG_au_2.6_0_0, ['0', '0']),
#  Call(sample=Sb_NG_au_2.6_0_1, ['0', '0']),
#  Call(sample=Sb_NG_be_1.10_0_0, ['0', '0']),
#  Call(sample=Sb_NG_be_1.10_0_1, ['0', '0']),
#  Call(sample=Sb_NG_be_1.3_0_0, ['0', '0']),
#  Call(sample=Sb_NG_be_1.3_0_1, ['0', '0']),
#  Call(sample=Sb_NG_be_1.5_0_0, ['0', '0']),
#  Call(sample=Sb_NG_be_1.5_0_1, ['0', '0']),
#  Call(sample=Sb_NG_en_1.1_0_0, ['0', '0']),
#  Call(sample=Sb_NG_en_1.1_0_1, ['0', '0']),
#  Call(sample=Sh_NG_eb_6_2_0_0, ['0', '0']),
#  Call(sample=Sh_NG_eb_6_2_0_1, ['0', '0']),
#  Call(sample=Sh_NG_ed_1_3_0_0, ['0', '0']),
#  Call(sample=Sh_NG_ed_1_3_0_1, ['0', '0']),
#  Call(sample=Sh_NG_ed_3_2_0_0, ['0', '0']),
#  Call(sample=Sh_NG_ed_3_2_0_1, ['0', '0']),
#  Call(sample=Sh_NG_kb_2_1_0_0, ['0', '0']),
#  Call(sample=Sh_NG_kb_2_1_0_1, ['0', '0']),
#  Call(sample=Sh_NG_kw_1_10_0_0, ['0', '0']),
#  Call(sample=Sh_NG_kw_1_10_0_1, ['0', '0']),
#  Call(sample=Sh_NG_os_1_4_0_0, ['0', '0']),
#  Call(sample=Sh_NG_os_1_4_0_1, ['0', '0']),
#  Call(sample=bovis_ethiopia_SRR13579874_0_0, ['0', '0']),
#  Call(sample=bovis_ethiopia_SRR13579874_0_1, ['0', '0']),
#  Call(sample=bovis_keyna_SRR13579878_0_0, ['1', '1']),
#  Call(sample=bovis_keyna_SRR13579878_0_1, ['0', '0']),
#  Call(sample=bovis_senegal_SRR13579876_0_0, ['1', '1']),
#  Call(sample=bovis_senegal_SRR13579876_0_1, ['0', '0']),
#  Call(sample=bovis_tanzania_ERR103048_0_0, ['0', '0']),
#  Call(sample=bovis_tanzania_ERR103048_0_1, ['0', '0']),
#  Call(sample=margrebowiei_zambia_ERR310940_0_0, ['0', '0']),
#  Call(sample=margrebowiei_zambia_ERR310940_0_1, ['0', '0']),
#  Call(sample=sbo_cdivoire_foro_106_0_0, ['0', '0']),
#  Call(sample=sbo_cdivoire_foro_106_0_1, ['0', '0']),
#  Call(sample=sbo_cdivoire_foro_116_0_0, ['0', '0']),
#  Call(sample=sbo_cdivoire_foro_116_0_1, ['0', '0']),
#  Call(sample=sbo_cdivoire_noumousso_107_0_0, ['0', '0']),
#  Call(sample=sbo_cdivoire_noumousso_107_0_1, ['0', '0']),
#  Call(sample=sbo_cdivoire_noumousso_117_0_0, ['0', '0']),
#  Call(sample=sbo_cdivoire_noumousso_117_0_1, ['0', '0']),
#  Call(sample=sbo_cdivoire_raviart_108_0_0, ['0', '0']),
#  Call(sample=sbo_cdivoire_raviart_108_0_1, ['0', '0']),
#  Call(sample=sbo_cdivoire_raviart_109_0_0, ['0', '0']),
#  Call(sample=sbo_cdivoire_raviart_109_0_1, ['0', '0']),
#  Call(sample=sbo_niger_libore_154_0_0, ['0', '0']),
#  Call(sample=sbo_niger_libore_154_0_1, ['0', '0']),
#  Call(sample=sbo_niger_libore_155_0_0, ['0', '0']),
#  Call(sample=sbo_niger_libore_155_0_1, ['0', '0']),
#  Call(sample=sbo_niger_libore_160_0_0, ['0', '0']),
#  Call(sample=sbo_niger_libore_160_0_1, ['0', '0']),
#  Call(sample=sbo_niger_libore_162_0_0, ['0', '0']),
#  Call(sample=sbo_niger_libore_162_0_1, ['0', '0']),
#  Call(sample=sbo_niger_libore_163_0_0, ['0', '0']),
#  Call(sample=sbo_niger_libore_163_0_1, ['0', '0']),
#  Call(sample=sbo_niger_libore_164_0_0, ['0', '0']),
#  Call(sample=sbo_niger_libore_164_0_1, ['0', '0']),
#  Call(sample=sbo_niger_libore_170_0_0, ['0', '0']),
#  Call(sample=sbo_niger_libore_170_0_1, ['0', '0']),
#  Call(sample=sbo_niger_libore_171_0_0, ['0', '0']),
#  Call(sample=sbo_niger_libore_171_0_1, ['0', '0']),
#  Call(sample=sbo_niger_libore_172_0_0, ['0', '0']),
#  Call(sample=sbo_niger_libore_172_0_1, ['0', '0']),
#  Call(sample=sbo_niger_libore_175_0_0, ['0', '0']),
#  Call(sample=sbo_niger_libore_175_0_1, ['0', '0']),
#  Call(sample=sbo_niger_libore_176_0_0, ['0', '0']),
#  Call(sample=sbo_niger_libore_176_0_1, ['0', '0']),
#  Call(sample=sbo_uganda_apac13_35_0_0, ['0', '0']),
#  Call(sample=sbo_uganda_apac13_35_0_1, ['0', '0']),
#  Call(sample=sbo_uganda_runga_44_0_0, ['0', '0']),
#  Call(sample=sbo_uganda_runga_44_0_1, ['0', '0']),
#  Call(sample=sh_cameroon_SRR13579883_0_0, ['0', '0']),
#  Call(sample=sh_cameroon_SRR13579883_0_1, ['0', '0']),
#  Call(sample=sh_egypt_SRR13579865_0_0, ['0', '0']),
#  Call(sample=sh_egypt_SRR13579865_0_1, ['0', '0']),
#  Call(sample=sh_egypt_SRR433862_0_0, ['0', '0']),
#  Call(sample=sh_egypt_SRR433862_0_1, ['0', '0']),
#  Call(sample=sh_gambia_SRR13579872_0_0, ['0', '0']),
#  Call(sample=sh_gambia_SRR13579872_0_1, ['0', '0']),
#  Call(sample=sh_guineabissau_SRR13579870_0_0, ['0', '0']),
#  Call(sample=sh_guineabissau_SRR13579870_0_1, ['0', '0']),
#  Call(sample=sh_ivorycoast_SRR13579866_0_0, ['0', '0']),
#  Call(sample=sh_ivorycoast_SRR13579866_0_1, ['0', '0']),
#  Call(sample=sh_mali_SRR13579867_0_0, ['0', '0']),
#  Call(sample=sh_mali_SRR13579867_0_1, ['0', '0']),
#  Call(sample=sh_niger_SRR8284786_0_0, ['0', '0']),
#  Call(sample=sh_niger_SRR8284786_0_1, ['0', '0']),
#  Call(sample=sh_niger_SRR8284787_0_0, ['0', '0']),
#  Call(sample=sh_niger_SRR8284787_0_1, ['0', '0']),
#  Call(sample=sh_niger_SRR8284788_0_0, ['0', '0']),
#  Call(sample=sh_niger_SRR8284788_0_1, ['0', '0']),
#  Call(sample=sh_niger_SRR8284789_0_0, ['0', '0']),
#  Call(sample=sh_niger_SRR8284789_0_1, ['0', '0']),
#  Call(sample=sh_niger_SRR8284790_0_0, ['0', '0']),
#  Call(sample=sh_niger_SRR8284790_0_1, ['0', '0']),
#  Call(sample=sh_niger_SRR8284791_0_0, ['0', '0']),
#  Call(sample=sh_niger_SRR8284791_0_1, ['0', '0']),
#  Call(sample=sh_nigeria_SRR13579869_0_0, ['0', '0']),
#  Call(sample=sh_nigeria_SRR13579869_0_1, ['0', '0']),
#  Call(sample=sh_senegal_SRR13579881_0_0, ['0', '0']),
#  Call(sample=sh_senegal_SRR13579881_0_1, ['0', '0']),
#  Call(sample=sh_tzpem_SRR8284792_0_0, ['0', '0']),
#  Call(sample=sh_tzpem_SRR8284792_0_1, ['0', '0']),
#  Call(sample=sh_tzpem_SRR8284794_0_0, ['0', '0']),
#  Call(sample=sh_tzpem_SRR8284794_0_1, ['0', '0']),
#  Call(sample=sh_tzpem_SRR8284796_0_0, ['0', '0']),
#  Call(sample=sh_tzpem_SRR8284796_0_1, ['0', '0']),
#  Call(sample=sh_tzpem_SRR8284797_0_0, ['0', '0']),
#  Call(sample=sh_tzpem_SRR8284797_0_1, ['0', '0']),
#  Call(sample=sh_zanzibar_SRR13579868_0_0, ['0', '0']),
#  Call(sample=sh_zanzibar_SRR13579868_0_1, ['0', '0']),
#  Call(sample=sha_angola_cota_57_0_0, ['0', '0']),
#  Call(sample=sha_angola_cota_57_0_1, ['0', '0']),
#  Call(sample=sha_angola_cota_58_0_0, ['0', '0']),
#  Call(sample=sha_angola_cota_58_0_1, ['0', '0']),
#  Call(sample=sha_angola_cota_59_0_0, ['0', '0']),
#  Call(sample=sha_angola_cota_59_0_1, ['0', '0']),
#  Call(sample=sha_angola_icau_60_0_0, ['0', '0']),
#  Call(sample=sha_angola_icau_60_0_1, ['0', '0']),
#  Call(sample=sha_angola_icau_61_0_0, ['0', '0']),
#  Call(sample=sha_angola_icau_61_0_1, ['0', '0']),
#  Call(sample=sha_angola_icau_62_0_0, ['0', '0']),
#  Call(sample=sha_angola_icau_62_0_1, ['0', '0']),
#  Call(sample=sha_angola_icau_63_0_0, ['0', '0']),
#  Call(sample=sha_angola_icau_63_0_1, ['0', '0']),
#  Call(sample=sha_angola_icau_64_0_0, ['0', '0']),
#  Call(sample=sha_angola_icau_64_0_1, ['0', '0']),
#  Call(sample=sha_cdivoire_kongobo_115_0_0, ['0', '0']),
#  Call(sample=sha_cdivoire_kongobo_115_0_1, ['0', '0']),
#  Call(sample=sha_kenya_unk_49_0_0, ['0', '0']),
#  Call(sample=sha_kenya_unk_49_0_1, ['0', '0']),
#  Call(sample=sha_liberia_dormeyan_54_0_0, ['0', '0']),
#  Call(sample=sha_liberia_dormeyan_54_0_1, ['0', '0']),
#  Call(sample=sha_liberia_joekpenmue_55_0_0, ['0', '0']),
#  Call(sample=sha_liberia_joekpenmue_55_0_1, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_73_0_0, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_73_0_1, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_74_0_0, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_74_0_1, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_75_0_0, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_75_0_1, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_76_0_0, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_76_0_1, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_77_0_0, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_77_0_1, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_78_0_0, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_78_0_1, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_80_0_0, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_80_0_1, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_81_0_0, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_81_0_1, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_82_0_0, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_82_0_1, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_83_0_0, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_83_0_1, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_84_0_0, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_84_0_1, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_87_0_0, ['0', '0']),
#  Call(sample=sha_madag_belesalampy_87_0_1, ['0', '0']),
#  Call(sample=sha_namib_mayenzere_134_0_0, ['0', '0']),
#  Call(sample=sha_namib_mayenzere_134_0_1, ['0', '0']),
#  Call(sample=sha_niger_libore_138_0_0, ['0', '0']),
#  Call(sample=sha_niger_libore_138_0_1, ['0', '0']),
#  Call(sample=sha_niger_libore_139_0_0, ['0', '0']),
#  Call(sample=sha_niger_libore_139_0_1, ['0', '0']),
#  Call(sample=sha_niger_libore_140_0_0, ['0', '0']),
#  Call(sample=sha_niger_libore_140_0_1, ['0', '0']),
#  Call(sample=sha_niger_libore_141_0_0, ['0', '0']),
#  Call(sample=sha_niger_libore_141_0_1, ['0', '0']),
#  Call(sample=sha_niger_libore_142_0_0, ['0', '0']),
#  Call(sample=sha_niger_libore_142_0_1, ['0', '0']),
#  Call(sample=sha_niger_libore_143_0_0, ['0', '0']),
#  Call(sample=sha_niger_libore_143_0_1, ['0', '0']),
#  Call(sample=sha_niger_libore_146_0_0, ['0', '0']),
#  Call(sample=sha_niger_libore_146_0_1, ['0', '0']),
#  Call(sample=sha_niger_libore_147_0_0, ['0', '0']),
#  Call(sample=sha_niger_libore_147_0_1, ['0', '0']),
#  Call(sample=sha_niger_libore_148_0_0, ['0', '0']),
#  Call(sample=sha_niger_libore_148_0_1, ['0', '0']),
#  Call(sample=sha_niger_libore_149_0_0, ['0', '0']),
#  Call(sample=sha_niger_libore_149_0_1, ['0', '0']),
#  Call(sample=sha_niger_libore_150_0_0, ['0', '0']),
#  Call(sample=sha_niger_libore_150_0_1, ['0', '0']),
#  Call(sample=sha_niger_libore_151_0_0, ['0', '0']),
#  Call(sample=sha_niger_libore_151_0_1, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_1_0_0, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_1_0_1, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_10_0_0, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_10_0_1, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_11_0_0, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_11_0_1, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_12_0_0, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_12_0_1, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_13_0_0, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_13_0_1, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_15_0_0, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_15_0_1, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_2_0_0, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_2_0_1, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_5_0_0, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_5_0_1, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_7_0_0, ['0', '0']),
#  Call(sample=sha_pemba_uwandani_7_0_1, ['0', '0']),
#  Call(sample=sha_sudan_canal4_125_0_0, ['0', '0']),
#  Call(sample=sha_sudan_canal4_125_0_1, ['0', '0']),
#  Call(sample=sha_sudan_canal4_126_0_0, ['0', '0']),
#  Call(sample=sha_sudan_canal4_126_0_1, ['0', '0']),
#  Call(sample=sha_sudan_canal4_127_0_0, ['0', '0']),
#  Call(sample=sha_sudan_canal4_127_0_1, ['0', '0']),
#  Call(sample=sha_sudan_canal4_132_0_0, ['0', '0']),
#  Call(sample=sha_sudan_canal4_132_0_1, ['0', '0']),
#  Call(sample=sha_sudan_schoole_120_0_0, ['0', '0']),
#  Call(sample=sha_sudan_schoole_120_0_1, ['0', '0']),
#  Call(sample=sha_sudan_schoolh_123_0_0, ['0', '0']),
#  Call(sample=sha_sudan_schoolh_123_0_1, ['0', '0']),
#  Call(sample=sha_sudan_schooli_129_0_0, ['0', '0']),
#  Call(sample=sha_sudan_schooli_129_0_1, ['0', '0']),
#  Call(sample=sha_sudan_schooli_130_0_0, ['0', '0']),
#  Call(sample=sha_sudan_schooli_130_0_1, ['0', '0']),
#  Call(sample=sha_swaz_mkhuzweni_177_0_0, ['0', '0']),
#  Call(sample=sha_swaz_mkhuzweni_177_0_1, ['0', '0']),
#  Call(sample=sha_swaz_mkhuzweni_178_0_0, ['0', '0']),
#  Call(sample=sha_swaz_mkhuzweni_178_0_1, ['0', '0']),
#  Call(sample=sha_swaz_mkhuzweni_179_0_0, ['0', '0']),
#  Call(sample=sha_swaz_mkhuzweni_179_0_1, ['0', '0']),
#  Call(sample=sha_swaz_mkhuzweni_180_0_0, ['0', '0']),
#  Call(sample=sha_swaz_mkhuzweni_180_0_1, ['0', '0']),
#  Call(sample=sha_swaz_mkhuzweni_182_0_0, ['0', '0']),
#  Call(sample=sha_swaz_mkhuzweni_182_0_1, ['0', '0']),
#  Call(sample=sha_swaz_mkhuzweni_184_0_0, ['0', '0']),
#  Call(sample=sha_swaz_mkhuzweni_184_0_1, ['0', '0']),
#  Call(sample=sha_swaz_njojane_188_0_0, ['0', '0']),
#  Call(sample=sha_swaz_njojane_188_0_1, ['0', '0']),
#  Call(sample=sha_swaz_njojane_190_0_0, ['0', '0']),
#  Call(sample=sha_swaz_njojane_190_0_1, ['0', '0']),
#  Call(sample=sha_swaz_njojane_191_0_0, ['0', '0']),
#  Call(sample=sha_swaz_njojane_191_0_1, ['0', '0']),
#  Call(sample=sha_swaz_qomintaba_185_0_0, ['0', '0']),
#  Call(sample=sha_swaz_qomintaba_185_0_1, ['0', '0']),
#  Call(sample=sha_swaz_unk_186_0_0, ['0', '0']),
#  Call(sample=sha_swaz_unk_186_0_1, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_16_0_0, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_16_0_1, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_19_0_0, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_19_0_1, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_23_0_0, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_23_0_1, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_25_0_0, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_25_0_1, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_26_0_0, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_26_0_1, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_27_0_0, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_27_0_1, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_28_0_0, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_28_0_1, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_29_0_0, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_29_0_1, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_30_0_0, ['0', '0']),
#  Call(sample=sha_unguja_kinyasini_30_0_1, ['0', '0']),
#  Call(sample=sha_zambia_lishiko_66_0_0, ['0', '0']),
#  Call(sample=sha_zambia_lishiko_66_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_allokokro_102_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_allokokro_102_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_foro_101_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_foro_101_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_foro_103_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_foro_103_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_kongobo_95_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_kongobo_95_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_kongobo_96_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_kongobo_96_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_kongobo_97_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_kongobo_97_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_kongobo_98_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_kongobo_98_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_linguebo_100_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_linguebo_100_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_linguebo_105_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_linguebo_105_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_noumousso_88_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_noumousso_88_0_1, ['1', '1']),
#  Call(sample=ssp_cdivoire_noumousso_94_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_noumousso_94_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_110_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_110_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_111_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_111_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_113_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_113_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_114_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_114_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_89_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_89_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_90_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_90_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_91_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_91_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_92_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_92_0_1, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_99_0_0, ['0', '0']),
#  Call(sample=ssp_cdivoire_raviart_99_0_1, ['0', '0']),
#  Call(sample=ssp_niger_libore_156_0_0, ['0', '0']),
#  Call(sample=ssp_niger_libore_156_0_1, ['0', '0']),
#  Call(sample=ssp_niger_libore_157_0_0, ['0', '0']),
#  Call(sample=ssp_niger_libore_157_0_1, ['0', '0']),
#  Call(sample=ssp_niger_libore_159_0_0, ['0', '0']),
#  Call(sample=ssp_niger_libore_159_0_1, ['0', '0']),
#  Call(sample=ssp_niger_libore_165_0_0, ['0', '0']),
#  Call(sample=ssp_niger_libore_165_0_1, ['0', '0']),
#  Call(sample=ssp_niger_libore_166_0_0, ['0', '0']),
#  Call(sample=ssp_niger_libore_166_0_1, ['0', '0']),
#  Call(sample=ssp_niger_libore_167_0_0, ['0', '0']),
#  Call(sample=ssp_niger_libore_167_0_1, ['0', '0']),
#  Call(sample=ssp_niger_libore_168_0_0, ['0', '0']),
#  Call(sample=ssp_niger_libore_168_0_1, ['0', '0']),
#  Call(sample=ssp_niger_libore_169_0_0, ['0', '0']),
#  Call(sample=ssp_niger_libore_169_0_1, ['0', '0']),
#  Call(sample=ssp_zambia_kafue_71_0_0, ['0', '0']),
#  Call(sample=ssp_zambia_kafue_71_0_1, ['0', '0'])]
